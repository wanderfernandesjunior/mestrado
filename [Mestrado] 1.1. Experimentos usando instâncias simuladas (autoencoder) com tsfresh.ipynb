# %% [markdown]
# ## [Mestrado] 1.1. Experimentos usando instâncias simuladas (autoencoder) com tsfresh

# %% [markdown]
# ## Bibliotecas e configurações

# %%
# Artifício para alcular tempo total do notebook Jupyter
from datetime import datetime 
start_time = datetime.now()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import logging
import warnings
import sys
import tensorflow as tf
tf.autograph.set_verbosity(0)
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
from math import ceil
from matplotlib import pyplot as plt
from time import time
from pathlib import Path
from tsfresh.feature_extraction import extract_features
from tsfresh.utilities.dataframe_functions import impute
from tsfresh.feature_extraction import MinimalFCParameters
from sklearn.svm import OneClassSVM
from sklearn.covariance import EllipticEnvelope
from sklearn.neighbors import LocalOutlierFactor
from sklearn.ensemble import IsolationForest
from sklearn.dummy import DummyClassifier
from sklearn import preprocessing
from sklearn.metrics import precision_recall_fscore_support
from sklearn.model_selection import ParameterGrid
from pyod.models.auto_encoder import AutoEncoder

# %%
logging.getLogger('tsfresh').setLevel(logging.ERROR)
warnings.simplefilter(action='ignore')

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'

# %%
data_path = Path('./', 'data')
random_state = 1
np.random.seed(random_state)
events_names = {0: 'Normal',
                1: 'Aumento Abrupto de BSW',
                2: 'Fechamento Espúrio de DHSV',
                3: 'Intermitência Severa',
                4: 'Instabilidade de Fluxo',
                5: 'Perda Rápida de Produtividade',
                6: 'Restrição Rápida em CKP',
                7: 'Incrustação em CKP',
                8: 'Hidrato em Linha de Produção'
               }
vars = ['P-PDG',
        'P-TPT',
        'T-TPT',
        'P-MON-CKP',
        'T-JUS-CKP',
        'P-JUS-CKGL',
        'T-JUS-CKGL',
        'QGL']
columns = ['timestamp'] + vars + ['class'] 
normal_class_code = 0
abnormal_classes_codes = [1, 2, 5, 6, 7, 8]
sample_size = 3*60              # Nas observações = segundos
min_normal_period_size = 20*60  # Nas observações = segundos
split_range = 0.6               # Porcentagem de separação entre treino/teste
max_samples_per_period = 15     # limitação por 'segurança'
df_fc_p = MinimalFCParameters() # Ver documentação da biblioteca tsfresh
df_fc_p.pop('sum_values')       # Remove feature inapropriada
df_fc_p.pop('length')           # Remove feature inapropriada
max_nan_percent = 0.1           # Para seleção de variáveis úteis
std_vars_min = 0.01             # Para seleção de variáveis úteis
clfs = {}                       # Dicionário para lista de classificadores a serem experimentados
disable_progressbar = True      # Para menos saídas no notebook

# %%
def class_and_file_generator(data_path, real=False, simulated=False, drawn=False):
    """Gerador de lista contendo número da classe e caminho do arquivo de acordo com a fonte da instância."""    
    for class_path in data_path.iterdir():
        if class_path.is_dir():
            class_code = int(class_path.stem)
            for instance_path in class_path.iterdir():
                if (instance_path.suffix == '.csv'):
                    if (simulated and instance_path.stem.startswith('SIMULATED')) or \
                       (drawn and instance_path.stem.startswith('DRAWN')) or \
                       (real and (not instance_path.stem.startswith('SIMULATED')) and \
                       (not instance_path.stem.startswith('DRAWN'))):
                        yield class_code, instance_path

# %%
def load_instance(instance_path):
    """Função que carrega cada instância individualmente"""
    try:
        well, instance_id = instance_path.stem.split('_')
        df = pd.read_csv(instance_path, sep=',', header=0)
        assert (df.columns == columns).all(), \
            f'Colunas inválidas no arquivo {str(instance_path)}: {str(df.columns.tolist())}'
        return df
    except Exception as e:
        raise Exception(f'Erro ao ler arquivo {instance_path}: {e}')

# %%
def extract_samples(df, class_code):
    # Obtém os rótulos das observações e seu conjunto inequívoco
    ols = list(df['class'])
    set_ols = set()
    for ol in ols:
        if ol in set_ols or np.isnan(ol):
            continue
        set_ols.add(int(ol))       
    
    # Descarta os rótulos das observações e substitui todos os nan por 0
    # (requisito da biblioteca tsfresh)
    df_vars = df.drop('class', axis=1).fillna(0)  
    
    # Inicializa objetos que serão retornados
    df_samples_train = pd.DataFrame()
    df_samples_test = pd.DataFrame()
    y_train = []
    y_test = []
            
    # Descubre o número máximo de amostras em períodos normais, transitórios e em regime
    # Obtém índices (primeiro e último) sem sobreposição com outros períodos
    f_idx = ols.index(normal_class_code)
    l_idx = len(ols)-1-ols[::-1].index(normal_class_code)

    # Define o número inicial de amostras para o período normal
    max_samples_normal = l_idx-f_idx+1-sample_size
    if (max_samples_normal) > 0:      
        num_normal_samples = min(max_samples_per_period, max_samples_normal)
        num_train_samples = int(split_range*num_normal_samples)
        num_test_samples = num_normal_samples - num_train_samples    
    else:
        num_train_samples = 0
        num_test_samples = 0
    
    # Define o número máximo de amostras por período transitório
    transient_code = class_code + 100    
    if transient_code in set_ols:
        # Obtém índices (primeiro e último) com possível sobreposição
        # no início do período
        f_idx = ols.index(transient_code)
        if f_idx-(sample_size-1) > 0:
            f_idx = f_idx-(sample_size-1)
        else:
            f_idx = 0
        l_idx = len(ols)-1-ols[::-1].index(transient_code)        
        max_transient_samples = l_idx-f_idx+1-sample_size
    else:
        max_transient_samples = 0            

    # Define o número máximo de amostras no período de regime
    if class_code in set_ols:
        # Obtém índices (primeiro e último) com possível sobreposição 
        # no início ou fim do período
        f_idx = ols.index(class_code)
        if f_idx-(sample_size-1) > 0:
            f_idx = f_idx-(sample_size-1)
        else:
            f_idx = 0
        l_idx = len(ols)-1-ols[::-1].index(class_code)
        if l_idx+(sample_size-1) < len(ols)-1:
            l_idx = l_idx+(sample_size-1) 
        else:
            l_idx = len(ols)-1
        max_in_regime_samples = l_idx-f_idx+1-sample_size
    else:
        max_in_regime_samples = 0   
        
    # Descubre o número adequado de amostras em períodos normais, transitórios e em regime
    num_transient_samples = ceil(num_test_samples/2)
    num_in_regime_samples = num_test_samples - num_transient_samples
    if (max_transient_samples >= num_transient_samples) and \
       (max_in_regime_samples < num_in_regime_samples):
        num_in_regime_samples = max_in_regime_samples        
        num_transient_samples = min(num_test_samples-num_in_regime_samples, max_transient_samples)
    elif (max_transient_samples < num_transient_samples) and \
         (max_in_regime_samples >= num_in_regime_samples):
        num_transient_samples = max_transient_samples        
        num_in_regime_samples = min(num_test_samples-num_transient_samples, max_in_regime_samples)
    elif (max_transient_samples < num_transient_samples) and \
         (max_in_regime_samples < num_in_regime_samples):
        num_transient_samples = max_transient_samples
        num_in_regime_samples = max_in_regime_samples
        num_test_samples = num_transient_samples+num_in_regime_samples
    
    # Extrai amostras do período normal para treinamento e teste
    # Obtém índices (primeiro e último) sem sobreposição com outros períodos
    f_idx = ols.index(normal_class_code)
    l_idx = len(ols)-1-ols[::-1].index(normal_class_code)
    
    # Define a etapa correta e extrai amostras
    if (num_normal_samples) > 0:  
        if num_normal_samples == max_samples_normal:
            step_max = 1 
        else:
            step_max = (max_samples_normal-1) // (max_samples_per_period-1)
        step_wanted = sample_size
        step = min(step_wanted, step_max)
        
        # Extrai amostras para treinamento
        sample_id = 0
        for idx in range(num_train_samples):
            f_idx_c = l_idx-sample_size+1-(num_normal_samples-1-idx)*step
            l_idx_c = f_idx_c+sample_size
            df_sample = df_vars.iloc[f_idx_c:l_idx_c, :]
            df_sample.insert(loc=0, column='id', value=sample_id)
            df_samples_train = df_samples_train.append(df_sample)
            y_train.append(normal_class_code)
            sample_id += 1
    
        # Extrai amostras para teste
        sample_id = 0
        for idx in range(num_train_samples, num_train_samples+num_test_samples):
            f_idx_c = l_idx-sample_size+1-(num_normal_samples-1-idx)*step
            l_idx_c = f_idx_c+sample_size
            df_sample = df_vars.iloc[f_idx_c:l_idx_c, :]
            df_sample.insert(loc=0, column='id', value=sample_id)
            df_samples_test = df_samples_test.append(df_sample)
            y_test.append(normal_class_code)
            sample_id += 1

    # Extrai amostras do período transitório (se existir) para teste
    if (num_transient_samples) > 0:    
        # Define a etapa correta e extrai amostras
        if num_transient_samples == max_transient_samples:
            step_max = 1 
        else:
            step_max = (max_transient_samples-1) // (max_samples_per_period-1)
        step_wanted = np.inf
        step = min(step_wanted, step_max)
        
        # Obtém índices (primeiro e último) com possível sobreposição no início deste período
        f_idx = ols.index(transient_code)
        if f_idx-(sample_size-1) > 0:
            f_idx = f_idx-(sample_size-1)
        else:
            f_idx = 0
        l_idx = len(ols)-1-ols[::-1].index(transient_code) 

        # Extrai amostras
        for idx in range(num_transient_samples):
            f_idx_c = f_idx+idx*step
            l_idx_c = f_idx_c+sample_size
            df_sample = df_vars.iloc[f_idx_c:l_idx_c, :]
            df_sample.insert(loc=0, column='id', value=sample_id)
            df_samples_test = df_samples_test.append(df_sample)
            y_test.append(transient_code)
            sample_id += 1
            
    # Extrai amostras do período em regime (se existir) para teste
    if (num_in_regime_samples) > 0:     
        # Define a etapa correta e extrai amostras
        if num_in_regime_samples == max_in_regime_samples:
            step_max = 1 
        else:
            step_max = (max_in_regime_samples-1) // (max_samples_per_period-1)
        step_wanted = sample_size
        step = min(step_wanted, step_max)
        
        # Obtém índices (primeiro e último) com possível sobreposição 
        # no início ou no final deste período
        f_idx = ols.index(class_code)
        if f_idx-(sample_size-1) > 0:
            f_idx = f_idx-(sample_size-1)
        else:
            f_idx = 0
        l_idx = len(ols)-1-ols[::-1].index(class_code)
        if l_idx+(sample_size-1) < len(ols)-1:
            l_idx = l_idx+(sample_size-1) 
        else:
            l_idx = len(ols)-1

        # Extrai amostras
        for idx in range(num_in_regime_samples):
            f_idx_c = f_idx+idx*step
            l_idx_c = f_idx_c+sample_size
            df_sample = df_vars.iloc[f_idx_c:l_idx_c, :]
            df_sample.insert(loc=0, column='id', value=sample_id)
            df_samples_test = df_samples_test.append(df_sample)
            y_test.append(class_code)
            sample_id += 1

    return df_samples_train, y_train, df_samples_test, y_test

# %%
def train_test_calc_scores(X_train, y_train, X_test, y_test, scores, clfs):
    X_train.reset_index(inplace=True, drop=True)
    X_test.reset_index(inplace=True, drop=True)    
    for clf_name, clf in clfs.items():
        
        # Treino
        t0 = time()
        clf.fit(X_train)
        t_train = time() - t0

        # Teste
        t0 = time()
        y_pred = clf.predict(X_test)
        t_test = time() - t0

        # Calcula as metricas de desempenho
        ret = precision_recall_fscore_support(y_test, y_pred, average='micro')
        p, r, f1, _ = ret
        scores = scores.append({'CLASSIFICADOR': clf_name, 
                                'PRECISAO': p,
                                'REVOGACAO': r,
                                'F1': f1,
                                'TREINAMENTO [s]': t_train, 
                                'TESTE [s] ': t_test}, ignore_index=True)  
    return scores

# %%
# Gets all selected instances but maintains only those with any type of undesirable event
simulated_instances = pd.DataFrame(class_and_file_generator(data_path, 
                                                       real=False,
                                                       simulated=True, 
                                                       drawn=False),
                              columns=['class_code', 'instance_path'])
simulated_instances = simulated_instances.loc[simulated_instances.iloc[:,0].isin(abnormal_classes_codes)].reset_index(drop=True)

# %%
# For each real instance with any type of undesirable event
scores = pd.DataFrame()
ignored_instances = 0
used_instances = 0

for i, row in simulated_instances.iterrows():
    # Loads the current instance
    class_code, instance_path = row
    print(f'Instância {i+1}: {instance_path}')
    df = load_instance(instance_path)
    
    # Ignores instances without sufficient normal periods
    normal_period_size = (df['class']==float(normal_class_code)).sum()
    if normal_period_size < min_normal_period_size:
        ignored_instances += 1
        print(f'\tignorado porque normal_period_size é insuficiente para treinamento ({normal_period_size})\n')
        continue
    used_instances += 1
        
    # Extracts samples from the current real instance
    ret = extract_samples(df, class_code)
    df_samples_train, y_train, df_samples_test, y_test = ret

    # Changes types of the labels (tsfresh's requirement)
    y_train = np.array(y_train)
    y_test = np.array(y_test)

    # We want binary classification: 0 stands for inliers and 1 for outliers/anomalies
    # (pyod's requirement)
    y_train[y_train!=normal_class_code] = 1
    y_train[y_train==normal_class_code] = 0   
    y_test[y_test!=normal_class_code] = 1
    y_test[y_test==normal_class_code] = 0
    
    # Drops the bad vars
    good_vars = np.isnan(df_samples_train[vars]).mean(0) <= max_nan_percent
    std_vars = np.nanstd(df_samples_train[vars], 0)
    good_vars &= (std_vars > std_vars_min)    
    good_vars = list(good_vars.index[good_vars])
    bad_vars = list(set(vars)-set(good_vars))
    df_samples_train.drop(columns=bad_vars, inplace=True, errors='ignore')
    df_samples_test.drop(columns=bad_vars, inplace=True, errors='ignore')
    
    # Normalizes the samples (zero mean and unit variance)
    scaler = preprocessing.StandardScaler()
    df_samples_train[good_vars] = scaler.fit_transform(df_samples_train[good_vars]).astype('float32')
    df_samples_test[good_vars] = scaler.transform(df_samples_test[good_vars]).astype('float32')
    
    # Extracts features from samples
    X_train = extract_features(df_samples_train, 
                               column_id='id', 
                               column_sort='timestamp', 
                               default_fc_parameters=df_fc_p,
                               impute_function=impute,
                               n_jobs=0,
                               disable_progressbar=disable_progressbar)
    X_train = X_train.reset_index(drop=True)
    X_test = extract_features(df_samples_test, 
                              column_id='id', 
                              column_sort='timestamp',
                              default_fc_parameters=df_fc_p,
                              impute_function=impute,
                              n_jobs=0,
                              disable_progressbar=disable_progressbar)
    X_test = X_test.reset_index(drop=True)

    # LISTA DE CLASSIFICADORES A SEREM EXPERIMENTADOS
    
    # AUTOENCODER - Combinações
    grid_params = {
    'hidden_neurons': [[8, 4, 4, 8], [4, 2, 2, 4]],
    'epochs': [10],
    'dropout': [0, 0.2],
    'batch_size': [4, 8]
    }
    
    for params in ParameterGrid(grid_params):
        clfs[f'AutoEncoder {params}'] = AutoEncoder(hidden_neurons=params['hidden_neurons'], hidden_activation='relu', output_activation='sigmoid', 
                                       loss='mae', optimizer='adam', epochs=params['epochs'], batch_size=params['batch_size'], 
                                       dropout_rate=params['dropout'], l2_regularizer=0.1, validation_size=0.1, preprocessing=False, 
                                       verbose=0, random_state=random_state, contamination=0.1)
        
    # Trains, tests and calculates the scores    
    scores = train_test_calc_scores(X_train, y_train, X_test, y_test, scores, clfs)
# Out:
# Instância 1: data\1\SIMULATED_00001.csv
# Instância 2: data\1\SIMULATED_00002.csv
# Instância 3: data\1\SIMULATED_00003.csv
# Instância 4: data\1\SIMULATED_00004.csv
# Instância 5: data\1\SIMULATED_00005.csv
# Instância 6: data\1\SIMULATED_00006.csv
# Instância 7: data\1\SIMULATED_00007.csv
# Instância 8: data\1\SIMULATED_00008.csv
# Instância 9: data\1\SIMULATED_00009.csv
# Instância 10: data\1\SIMULATED_00010.csv
# Instância 11: data\1\SIMULATED_00011.csv
# Instância 12: data\1\SIMULATED_00012.csv
# Instância 13: data\1\SIMULATED_00013.csv
# Instância 14: data\1\SIMULATED_00014.csv
# Instância 15: data\1\SIMULATED_00015.csv
# Instância 16: data\1\SIMULATED_00016.csv
# Instância 17: data\1\SIMULATED_00017.csv
# Instância 18: data\1\SIMULATED_00018.csv
# Instância 19: data\1\SIMULATED_00019.csv
# Instância 20: data\1\SIMULATED_00020.csv
# Instância 21: data\1\SIMULATED_00021.csv
# Instância 22: data\1\SIMULATED_00022.csv
# Instância 23: data\1\SIMULATED_00023.csv
# Instância 24: data\1\SIMULATED_00024.csv
# Instância 25: data\1\SIMULATED_00025.csv
# Instância 26: data\1\SIMULATED_00026.csv
# Instância 27: data\1\SIMULATED_00027.csv
# Instância 28: data\1\SIMULATED_00028.csv
# Instância 29: data\1\SIMULATED_00029.csv
# Instância 30: data\1\SIMULATED_00030.csv
# Instância 31: data\1\SIMULATED_00031.csv
# Instância 32: data\1\SIMULATED_00032.csv
# Instância 33: data\1\SIMULATED_00033.csv
# Instância 34: data\1\SIMULATED_00034.csv
# Instância 35: data\1\SIMULATED_00035.csv
# Instância 36: data\1\SIMULATED_00036.csv
# Instância 37: data\1\SIMULATED_00037.csv
# Instância 38: data\1\SIMULATED_00038.csv
# Instância 39: data\1\SIMULATED_00039.csv
# Instância 40: data\1\SIMULATED_00040.csv
# Instância 41: data\1\SIMULATED_00041.csv
# Instância 42: data\1\SIMULATED_00042.csv
# Instância 43: data\1\SIMULATED_00043.csv
# Instância 44: data\1\SIMULATED_00044.csv
# Instância 45: data\1\SIMULATED_00045.csv
# Instância 46: data\1\SIMULATED_00046.csv
# Instância 47: data\1\SIMULATED_00047.csv
# Instância 48: data\1\SIMULATED_00048.csv
# Instância 49: data\1\SIMULATED_00049.csv
# Instância 50: data\1\SIMULATED_00050.csv
# Instância 51: data\1\SIMULATED_00051.csv
# Instância 52: data\1\SIMULATED_00052.csv
# Instância 53: data\1\SIMULATED_00053.csv
# Instância 54: data\1\SIMULATED_00054.csv
# Instância 55: data\1\SIMULATED_00055.csv
# Instância 56: data\1\SIMULATED_00056.csv
# Instância 57: data\1\SIMULATED_00057.csv
# Instância 58: data\1\SIMULATED_00058.csv
# Instância 59: data\1\SIMULATED_00059.csv
# Instância 60: data\1\SIMULATED_00060.csv
# Instância 61: data\1\SIMULATED_00061.csv
# Instância 62: data\1\SIMULATED_00062.csv
# Instância 63: data\1\SIMULATED_00063.csv
# Instância 64: data\1\SIMULATED_00064.csv
# Instância 65: data\1\SIMULATED_00065.csv
# Instância 66: data\1\SIMULATED_00066.csv
# Instância 67: data\1\SIMULATED_00067.csv
# Instância 68: data\1\SIMULATED_00068.csv
# Instância 69: data\1\SIMULATED_00069.csv
# Instância 70: data\1\SIMULATED_00070.csv
# Instância 71: data\1\SIMULATED_00071.csv
# Instância 72: data\1\SIMULATED_00072.csv
# Instância 73: data\1\SIMULATED_00073.csv
# Instância 74: data\1\SIMULATED_00074.csv
# Instância 75: data\1\SIMULATED_00075.csv
# Instância 76: data\1\SIMULATED_00076.csv
# Instância 77: data\1\SIMULATED_00077.csv
# Instância 78: data\1\SIMULATED_00078.csv
# Instância 79: data\1\SIMULATED_00079.csv
# Instância 80: data\1\SIMULATED_00080.csv
# Instância 81: data\1\SIMULATED_00081.csv
# Instância 82: data\1\SIMULATED_00082.csv
# Instância 83: data\1\SIMULATED_00083.csv
# Instância 84: data\1\SIMULATED_00084.csv
# Instância 85: data\1\SIMULATED_00085.csv
# Instância 86: data\1\SIMULATED_00086.csv
# Instância 87: data\1\SIMULATED_00087.csv
# Instância 88: data\1\SIMULATED_00088.csv
# Instância 89: data\1\SIMULATED_00089.csv
# Instância 90: data\1\SIMULATED_00090.csv
# Instância 91: data\1\SIMULATED_00091.csv
# Instância 92: data\1\SIMULATED_00092.csv
# Instância 93: data\1\SIMULATED_00093.csv
# Instância 94: data\1\SIMULATED_00094.csv
# Instância 95: data\1\SIMULATED_00095.csv
# Instância 96: data\1\SIMULATED_00096.csv
# Instância 97: data\1\SIMULATED_00097.csv
# Instância 98: data\1\SIMULATED_00098.csv
# Instância 99: data\1\SIMULATED_00099.csv
# Instância 100: data\1\SIMULATED_00100.csv
# Instância 101: data\1\SIMULATED_00101.csv
# Instância 102: data\1\SIMULATED_00102.csv
# Instância 103: data\1\SIMULATED_00103.csv
# Instância 104: data\1\SIMULATED_00104.csv
# Instância 105: data\1\SIMULATED_00105.csv
# Instância 106: data\1\SIMULATED_00106.csv
# Instância 107: data\1\SIMULATED_00107.csv
# Instância 108: data\1\SIMULATED_00108.csv
# Instância 109: data\1\SIMULATED_00109.csv
# Instância 110: data\1\SIMULATED_00110.csv
# Instância 111: data\1\SIMULATED_00111.csv
# Instância 112: data\1\SIMULATED_00112.csv
# Instância 113: data\1\SIMULATED_00113.csv
# Instância 114: data\1\SIMULATED_00114.csv
# Instância 115: data\2\SIMULATED_00001.csv
# Instância 116: data\2\SIMULATED_00002.csv
# Instância 117: data\2\SIMULATED_00003.csv
# Instância 118: data\2\SIMULATED_00004.csv
# Instância 119: data\2\SIMULATED_00005.csv
# Instância 120: data\2\SIMULATED_00006.csv
# Instância 121: data\2\SIMULATED_00007.csv
# Instância 122: data\2\SIMULATED_00008.csv
# Instância 123: data\2\SIMULATED_00009.csv
# Instância 124: data\2\SIMULATED_00010.csv
# Instância 125: data\2\SIMULATED_00011.csv
# Instância 126: data\2\SIMULATED_00012.csv
# Instância 127: data\2\SIMULATED_00013.csv
# Instância 128: data\2\SIMULATED_00014.csv
# Instância 129: data\2\SIMULATED_00015.csv
# Instância 130: data\2\SIMULATED_00016.csv
# Instância 131: data\5\SIMULATED_00001.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 132: data\5\SIMULATED_00002.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 133: data\5\SIMULATED_00003.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 134: data\5\SIMULATED_00004.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 135: data\5\SIMULATED_00005.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 136: data\5\SIMULATED_00006.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 137: data\5\SIMULATED_00007.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 138: data\5\SIMULATED_00008.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 139: data\5\SIMULATED_00009.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 140: data\5\SIMULATED_00010.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 141: data\5\SIMULATED_00011.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 142: data\5\SIMULATED_00012.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 143: data\5\SIMULATED_00013.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 144: data\5\SIMULATED_00014.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 145: data\5\SIMULATED_00015.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 146: data\5\SIMULATED_00016.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 147: data\5\SIMULATED_00017.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 148: data\5\SIMULATED_00018.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 149: data\5\SIMULATED_00019.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 150: data\5\SIMULATED_00020.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 151: data\5\SIMULATED_00021.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 152: data\5\SIMULATED_00022.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 153: data\5\SIMULATED_00023.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 154: data\5\SIMULATED_00024.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 155: data\5\SIMULATED_00025.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 156: data\5\SIMULATED_00026.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 157: data\5\SIMULATED_00027.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 158: data\5\SIMULATED_00028.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 159: data\5\SIMULATED_00029.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância
csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 547: data\5\SIMULATED_00417.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 548: data\5\SIMULATED_00418.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 549: data\5\SIMULATED_00419.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 550: data\5\SIMULATED_00420.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 551: data\5\SIMULATED_00421.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 552: data\5\SIMULATED_00422.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 553: data\5\SIMULATED_00423.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 554: data\5\SIMULATED_00424.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 555: data\5\SIMULATED_00425.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 556: data\5\SIMULATED_00426.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 557: data\5\SIMULATED_00427.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 558: data\5\SIMULATED_00428.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 559: data\5\SIMULATED_00429.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 560: data\5\SIMULATED_00430.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 561: data\5\SIMULATED_00431.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 562: data\5\SIMULATED_00432.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 563: data\5\SIMULATED_00433.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 564: data\5\SIMULATED_00434.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 565: data\5\SIMULATED_00435.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 566: data\5\SIMULATED_00436.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 567: data\5\SIMULATED_00437.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 568: data\5\SIMULATED_00438.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 569: data\5\SIMULATED_00439.csv
# 	ignorado porque normal_period_size é insuficiente para treinamento (500)
#
# Instância 570: data\6\SIMULATED_00001.csv
# Instância 571: data\6\SIMULATED_00002.csv
# Instância 572: data\6\SIMULATED_00003.csv
# Instância 573: data\6\SIMULATED_00004.csv
# Instância 574: data\6\SIMULATED_00005.csv
# Instância 575: data\6\SIMULATED_00006.csv
# Instância 576: data\6\SIMULATED_00007.csv
# Instância 577: data\6\SIMULATED_00008.csv
# Instância 578: data\6\SIMULATED_00009.csv
# Instância 579: data\6\SIMULATED_00010.csv
# Instância 580: data\6\SIMULATED_00011.csv
# Instância 581: data\6\SIMULATED_00012.csv
# Instância 582: data\6\SIMULATED_00013.csv
# Instância 583: data\6\SIMULATED_00014.csv
# Instância 584: data\6\SIMULATED_00015.csv
# Instância 585: data\6\SIMULATED_00016.csv
# Instância 586: data\6\SIMULATED_00017.csv
# Instância 587: data\6\SIMULATED_00018.csv
# Instância 588: data\6\SIMULATED_00019.csv
# Instância 589: data\6\SIMULATED_00020.csv
# Instância 590: data\6\SIMULATED_00021.csv
# Instância 591: data\6\SIMULATED_00022.csv
# Instância 592: data\6\SIMULATED_00023.csv
# Instância 593: data\6\SIMULATED_00024.csv
# Instância 594: data\6\SIMULATED_00025.csv
# Instância 595: data\6\SIMULATED_00026.csv
# Instância 596: data\6\SIMULATED_00027.csv
# Instância 597: data\6\SIMULATED_00028.csv
# Instância 598: data\6\SIMULATED_00029.csv
# Instância 599: data\6\SIMULATED_00030.csv
# Instância 600: data\6\SIMULATED_00031.csv
# Instância 601: data\6\SIMULATED_00032.csv
# Instância 602: data\6\SIMULATED_00033.csv
# Instância 603: data\6\SIMULATED_00034.csv
# Instância 604: data\6\SIMULATED_00035.csv
# Instância 605: data\6\SIMULATED_00036.csv
# Instância 606: data\6\SIMULATED_00037.csv
# Instância 607: data\6\SIMULATED_00038.csv
# Instância 608: data\6\SIMULATED_00039.csv
# Instância 609: data\6\SIMULATED_00040.csv
# Instância 610: data\6\SIMULATED_00041.csv
# Instância 611: data\6\SIMULATED_00042.csv
# Instância 612: data\6\SIMULATED_00043.csv
# Instância 613: data\6\SIMULATED_00044.csv
# Instância 614: data\6\SIMULATED_00045.csv
# Instância 615: data\6\SIMULATED_00046.csv
# Instância 616: data\6\SIMULATED_00047.csv
# Instância 617: data\6\SIMULATED_00048.csv
# Instância 618: data\6\SIMULATED_00049.csv
# Instância 619: data\6\SIMULATED_00050.csv
# Instância 620: data\6\SIMULATED_00051.csv
# Instância 621: data\6\SIMULATED_00052.csv
# Instância 622: data\6\SIMULATED_00053.csv
# Instância 623: data\6\SIMULATED_00054.csv
# Instância 624: data\6\SIMULATED_00055.csv
# Instância 625: data\6\SIMULATED_00056.csv
# Instância 626: data\6\SIMULATED_00057.csv
# Instância 627: data\6\SIMULATED_00058.csv
# Instância 628: data\6\SIMULATED_00059.csv
# Instância 629: data\6\SIMULATED_00060.csv
# Instância 630: data\6\SIMULATED_00061.csv
# Instância 631: data\6\SIMULATED_00062.csv
# Instância 632: data\6\SIMULATED_00063.csv
# Instância 633: data\6\SIMULATED_00064.csv
# Instância 634: data\6\SIMULATED_00065.csv
# Instância 635: data\6\SIMULATED_00066.csv
# Instância 636: data\6\SIMULATED_00067.csv
# Instância 637: data\6\SIMULATED_00068.csv
# Instância 638: data\6\SIMULATED_00069.csv
# Instância 639: data\6\SIMULATED_00070.csv
# Instância 640: data\6\SIMULATED_00071.csv
# Instância 641: data\6\SIMULATED_00072.csv
# Instância 642: data\6\SIMULATED_00073.csv
# Instância 643: data\6\SIMULATED_00074.csv
# Instância 644: data\6\SIMULATED_00075.csv
# Instância 645: data\6\SIMULATED_00076.csv
# Instância 646: data\6\SIMULATED_00077.csv
# Instância 647: data\6\SIMULATED_00078.csv
# Instância 648: data\6\SIMULATED_00079.csv
# Instância 649: data\6\SIMULATED_00080.csv
# Instância 650: data\6\SIMULATED_00081.csv
# Instância 651: data\6\SIMULATED_00082.csv
# Instância 652: data\6\SIMULATED_00083.csv
# Instância 653: data\6\SIMULATED_00084.csv
# Instância 654: data\6\SIMULATED_00085.csv
# Instância 655: data\6\SIMULATED_00086.csv
# Instância 656: data\6\SIMULATED_00087.csv
# Instância 657: data\6\SIMULATED_00088.csv
# Instância 658: data\6\SIMULATED_00089.csv
# Instância 659: data\6\SIMULATED_00090.csv
# Instância 660: data\6\SIMULATED_00091.csv
# Instância 661: data\6\SIMULATED_00092.csv
# Instância 662: data\6\SIMULATED_00093.csv
# Instância 663: data\6\SIMULATED_00094.csv
# Instância 664: data\6\SIMULATED_00095.csv
# Instância 665: data\6\SIMULATED_00096.csv
# Instância 666: data\6\SIMULATED_00097.csv
# Instância 667: data\6\SIMULATED_00098.csv
# Instância 668: data\6\SIMULATED_00099.csv
# Instância 669: data\6\SIMULATED_00100.csv
# Instância 670: data\6\SIMULATED_00101.csv
# Instância 671: data\6\SIMULATED_00102.csv
# Instância 672: data\6\SIMULATED_00103.csv
# Instância 673: data\6\SIMULATED_00104.csv
# Instância 674: data\6\SIMULATED_00105.csv
# Instância 675: data\6\SIMULATED_00106.csv
# Instância 676: data\6\SIMULATED_00107.csv
# Instância 677: data\6\SIMULATED_00108.csv
# Instância 678: data\6\SIMULATED_00109.csv
# Instância 679: data\6\SIMULATED_00110.csv
# Instância 680: data\6\SIMULATED_00111.csv
# Instância 681: data\6\SIMULATED_00112.csv
# Instância 682: data\6\SIMULATED_00113.csv
# Instância 683: data\6\SIMULATED_00114.csv
# Instância 684: data\6\SIMULATED_00115.csv
# Instância 685: data\6\SIMULATED_00116.csv
# Instância 686: data\6\SIMULATED_00117.csv
# Instância 687: data\6\SIMULATED_00118.csv
# Instância 688: data\6\SIMULATED_00119.csv
# Instância 689: data\6\SIMULATED_00120.csv
# Instância 690: data\6\SIMULATED_00121.csv
# Instância 691: data\6\SIMULATED_00122.csv
# Instância 692: data\6\SIMULATED_00123.csv
# Instância 693: data\6\SIMULATED_00124.csv
# Instância 694: data\6\SIMULATED_00125.csv
# Instância 695: data\6\SIMULATED_00126.csv
# Instância 696: data\6\SIMULATED_00127.csv
# Instância 697: data\6\SIMULATED_00128.csv
# Instância 698: data\6\SIMULATED_00129.csv
# Instância 699: data\6\SIMULATED_00130.csv
# Instância 700: data\6\SIMULATED_00131.csv
# Instância 701: data\6\SIMULATED_00132.csv
# Instância 702: data\6\SIMULATED_00133.csv
# Instância 703: data\6\SIMULATED_00134.csv
# Instância 704: data\6\SIMULATED_00135.csv
# Instância 705: data\6\SIMULATED_00136.csv
# Instância 706: data\6\SIMULATED_00137.csv
# Instância 707: data\6\SIMULATED_00138.csv
# Instância 708: data\6\SIMULATED_00139.csv
# Instância 709: data\6\SIMULATED_00140.csv
# Instância 710: data\6\SIMULATED_00141.csv
# Instância 711: data\6\SIMULATED_00142.csv
# Instância 712: data\6\SIMULATED_00143.csv
# Instância 713: data\6\SIMULATED_00144.csv
# Instância 714: data\6\SIMULATED_00145.csv
# Instância 715: data\6\SIMULATED_00146.csv
# Instância 716: data\6\SIMULATED_00147.csv
# Instância 717: data\6\SIMULATED_00148.csv
# Instância 718: data\6\SIMULATED_00149.csv
# Instância 719: data\6\SIMULATED_00150.csv
# Instância 720: data\6\SIMULATED_00151.csv
# Instância 721: data\6\SIMULATED_00152.csv
# Instância 722: data\6\SIMULATED_00153.csv
# Instância 723: data\6\SIMULATED_00154.csv
# Instância 724: data\6\SIMULATED_00155.csv
# Instância 725: data\6\SIMULATED_00156.csv
# Instância 726: data\6\SIMULATED_00157.csv
# Instância 727: data\6\SIMULATED_00158.csv
# Instância 728: data\6\SIMULATED_00159.csv
# Instância 729: data\6\SIMULATED_00160.csv
# Instância 730: data\6\SIMULATED_00161.csv
# Instância 731: data\6\SIMULATED_00162.csv
# Instância 732: data\6\SIMULATED_00163.csv
# Instância 733: data\6\SIMULATED_00164.csv
# Instância 734: data\6\SIMULATED_00165.csv
# Instância 735: data\6\SIMULATED_00166.csv
# Instância 736: data\6\SIMULATED_00167.csv
# Instância 737: data\6\SIMULATED_00168.csv
# Instância 738: data\6\SIMULATED_00169.csv
# Instância 739: data\6\SIMULATED_00170.csv
# Instância 740: data\6\SIMULATED_00171.csv
# Instância 741: data\6\SIMULATED_00172.csv
# Instância 742: data\6\SIMULATED_00173.csv
# Instância 743: data\6\SIMULATED_00174.csv
# Instância 744: data\6\SIMULATED_00175.csv
# Instância 745: data\6\SIMULATED_00176.csv
# Instância 746: data\6\SIMULATED_00177.csv
# Instância 747: data\6\SIMULATED_00178.csv
# Instância 748: data\6\SIMULATED_00179.csv
# Instância 749: data\6\SIMULATED_00180.csv
# Instância 750: data\6\SIMULATED_00181.csv
# Instância 751: data\6\SIMULATED_00182.csv
# Instância 752: data\6\SIMULATED_00183.csv
# Instância 753: data\6\SIMULATED_00184.csv
# Instância 754: data\6\SIMULATED_00185.csv
# Instância 755: data\6\SIMULATED_00186.csv
# Instância 756: data\6\SIMULATED_00187.csv
# Instância 757: data\6\SIMULATED_00188.csv
# Instância 758: data\6\SIMULATED_00189.csv
# Instância 759: data\6\SIMULATED_00190.csv
# Instância 760: data\6\SIMULATED_00191.csv
# Instância 761: data\6\SIMULATED_00192.csv
# Instância 762: data\6\SIMULATED_00193.csv
# Instância 763: data\6\SIMULATED_00194.csv
# Instância 764: data\6\SIMULATED_00195.csv
# Instância 765: data\6\SIMULATED_00196.csv
# Instância 766: data\6\SIMULATED_00197.csv
# Instância 767: data\6\SIMULATED_00198.csv
# Instância 768: data\6\SIMULATED_00199.csv
# Instância 769: data\6\SIMULATED_00200.csv
# Instância 770: data\6\SIMULATED_00201.csv
# Instância 771: data\6\SIMULATED_00202.csv
# Instância 772: data\6\SIMULATED_00203.csv
# Instância 773: data\6\SIMULATED_00204.csv
# Instância 774: data\6\SIMULATED_00205.csv
# Instância 775: data\6\SIMULATED_00206.csv
# Instância 776: data\6\SIMULATED_00207.csv
# Instância 777: data\6\SIMULATED_00208.csv
# Instância 778: data\6\SIMULATED_00209.csv
# Instância 779: data\6\SIMULATED_00210.csv
# Instância 780: data\6\SIMULATED_00211.csv
# Instância 781: data\6\SIMULATED_00212.csv
# Instância 782: data\6\SIMULATED_00213.csv
# Instância 783: data\6\SIMULATED_00214.csv
# Instância 784: data\6\SIMULATED_00215.csv
# Instância 785: data\8\SIMULATED_00001.csv
# Instância 786: data\8\SIMULATED_00002.csv
# Instância 787: data\8\SIMULATED_00003.csv
# Instância 788: data\8\SIMULATED_00004.csv
# Instância 789: data\8\SIMULATED_00005.csv
# Instância 790: data\8\SIMULATED_00006.csv
# Instância 791: data\8\SIMULATED_00007.csv
# Instância 792: data\8\SIMULATED_00008.csv
# Instância 793: data\8\SIMULATED_00009.csv
# Instância 794: data\8\SIMULATED_00010.csv
# Instância 795: data\8\SIMULATED_00011.csv
# Instância 796: data\8\SIMULATED_00012.csv
# Instância 797: data\8\SIMULATED_00013.csv
# Instância 798: data\8\SIMULATED_00014.csv
# Instância 799: data\8\SIMULATED_00015.csv
# Instância 800: data\8\SIMULATED_00016.csv
# Instância 801: data\8\SIMULATED_00017.csv
# Instância 802: data\8\SIMULATED_00018.csv
# Instância 803: data\8\SIMULATED_00019.csv
# Instância 804: data\8\SIMULATED_00020.csv
# Instância 805: data\8\SIMULATED_00021.csv
# Instância 806: data\8\SIMULATED_00022.csv
# Instância 807: data\8\SIMULATED_00023.csv
# Instância 808: data\8\SIMULATED_00024.csv
# Instância 809: data\8\SIMULATED_00025.csv
# Instância 810: data\8\SIMULATED_00026.csv
# Instância 811: data\8\SIMULATED_00027.csv
# Instância 812: data\8\SIMULATED_00028.csv
# Instância 813: data\8\SIMULATED_00029.csv
# Instância 814: data\8\SIMULATED_00030.csv
# Instância 815: data\8\SIMULATED_00031.csv
# Instância 816: data\8\SIMULATED_00032.csv
# Instância 817: data\8\SIMULATED_00033.csv
# Instância 818: data\8\SIMULATED_00034.csv
# Instância 819: data\8\SIMULATED_00035.csv
# Instância 820: data\8\SIMULATED_00036.csv
# Instância 821: data\8\SIMULATED_00037.csv
# Instância 822: data\8\SIMULATED_00038.csv
# Instância 823: data\8\SIMULATED_00039.csv
# Instância 824: data\8\SIMULATED_00040.csv
# Instância 825: data\8\SIMULATED_00041.csv
# Instância 826: data\8\SIMULATED_00042.csv
# Instância 827: data\8\SIMULATED_00043.csv
# Instância 828: data\8\SIMULATED_00044.csv
# Instância 829: data\8\SIMULATED_00045.csv
# Instância 830: data\8\SIMULATED_00046.csv
# Instância 831: data\8\SIMULATED_00047.csv
# Instância 832: data\8\SIMULATED_00048.csv
# Instância 833: data\8\SIMULATED_00049.csv
# Instância 834: data\8\SIMULATED_00050.csv
# Instância 835: data\8\SIMULATED_00051.csv
# Instância 836: data\8\SIMULATED_00052.csv
# Instância 837: data\8\SIMULATED_00053.csv
# Instância 838: data\8\SIMULATED_00054.csv
# Instância 839: data\8\SIMULATED_00055.csv
# Instância 840: data\8\SIMULATED_00056.csv
# Instância 841: data\8\SIMULATED_00057.csv
# Instância 842: data\8\SIMULATED_00058.csv
# Instância 843: data\8\SIMULATED_00059.csv
# Instância 844: data\8\SIMULATED_00060.csv
# Instância 845: data\8\SIMULATED_00061.csv
# Instância 846: data\8\SIMULATED_00062.csv
# Instância 847: data\8\SIMULATED_00063.csv
# Instância 848: data\8\SIMULATED_00064.csv
# Instância 849: data\8\SIMULATED_00065.csv
# Instância 850: data\8\SIMULATED_00066.csv
# Instância 851: data\8\SIMULATED_00067.csv
# Instância 852: data\8\SIMULATED_00068.csv
# Instância 853: data\8\SIMULATED_00069.csv
# Instância 854: data\8\SIMULATED_00070.csv
# Instância 855: data\8\SIMULATED_00071.csv
# Instância 856: data\8\SIMULATED_00072.csv
# Instância 857: data\8\SIMULATED_00073.csv
# Instância 858: data\8\SIMULATED_00074.csv
# Instância 859: data\8\SIMULATED_00075.csv
# Instância 860: data\8\SIMULATED_00076.csv
# Instância 861: data\8\SIMULATED_00077.csv
# Instância 862: data\8\SIMULATED_00078.csv
# Instância 863: data\8\SIMULATED_00079.csv
# Instância 864: data\8\SIMULATED_00080.csv
# Instância 865: data\8\SIMULATED_00081.csv

# %% [markdown]
# ## Resultados

# %% [markdown]
# Os resultados obtidos com os métodos implementados são apresentados abaixo.

# %%
print(f'Número de instâncias utilizadas: {used_instances}')
print(f'Número de instâncias ignoradas: {ignored_instances}')
# Out:
# Número de instâncias utilizadas: 426
# Número de instâncias ignoradas: 439

# %%
print(f'Características utilizadas: {list(df_fc_p.keys())}')
# Out:
# Características utilizadas: ['median', 'mean', 'standard_deviation', 'variance', 'root_mean_square', 'maximum', 'minimum']

# %% [markdown]
# Os comandos a seguir permitem salvar e recuperar os resultados de/para um arquivo CSV de forma conveniente.

# %%
scores.to_csv(r'./results/1-1_anomaly_detection_scores_simuladas.csv')

# %% [markdown]
# ### Métricas em formato tabular

# %% [markdown]
# As tabelas a seguir apresentam as médias e o desvio padrão das métricas, respectivamente. Ambos são ordenados pela medida-F1.

# %%
# Médias
mean_score_table = scores.groupby('CLASSIFICADOR').mean().sort_values(by=['F1'], ascending=False)
mean_score_table.to_csv(r'./results/1-1_anomaly_detection_scores_medias_simuladas.csv')
mean_score_table
# Out:
#                                                     PRECISAO  REVOGACAO  \
# CLASSIFICADOR
# AutoEncoder {'batch_size': 8, 'dropout': 0, 'ep...  0.724570   0.724570
# AutoEncoder {'batch_size': 8, 'dropout': 0.2, '...  0.724178   0.724178
# AutoEncoder {'batch_size': 8, 'dropout': 0.2, '...  0.723592   0.723592
# AutoEncoder {'batch_size': 4, 'dropout': 0.2, '...  0.723396   0.723396
# AutoEncoder {'batch_size': 8, 'dropout': 0, 'ep...  0.723396   0.723396
# AutoEncoder {'batch_size': 4, 'dropout': 0, 'ep...  0.722418   0.722418
# AutoEncoder {'batch_size': 4, 'dropout': 0.2, '...  0.722222   0.722222
# AutoEncoder {'batch_size': 4, 'dropout': 0, 'ep...  0.721440   0.721440
#
#                                                           F1  TREINAMENTO [s]  \
# CLASSIFICADOR
# AutoEncoder {'batch_size': 8, 'dropout': 0, 'ep...  0.724570         1.412069
# AutoEncoder {'batch_size': 8, 'dropout': 0.2, '...  0.724178         1.454235
# AutoEncoder {'batch_size': 8, 'dropout': 0.2, '...  0.723592         1.451255
# AutoEncoder {'batch_size': 4, 'dropout': 0.2, '...  0.723396         1.442581
# AutoEncoder {'batch_size': 8, 'dropout': 0, 'ep...  0.723396         1.400502
# AutoEncoder {'batch_size': 4, 'dropout': 0, 'ep...  0.722418         1.439893
# AutoEncoder {'batch_size': 4, 'dropout': 0.2, '...  0.722222         1.419095
# AutoEncoder {'batch_size': 4, 'dropout': 0, 'ep...  0.721440         1.379508
#
#                                                     TESTE [s]
# CLASSIFICADOR
# AutoEncoder {'batch_size': 8, 'dropout': 0, 'ep...    0.031674
# AutoEncoder {'batch_size': 8, 'dropout': 0.2, '...    0.031684
# AutoEncoder {'batch_size': 8, 'dropout': 0.2, '...    0.032959
# AutoEncoder {'batch_size': 4, 'dropout': 0.2, '...    0.031729
# AutoEncoder {'batch_size': 8, 'dropout': 0, 'ep...    0.032816
# AutoEncoder {'batch_size': 4, 'dropout': 0, 'ep...    0.031735
# AutoEncoder {'batch_size': 4, 'dropout': 0.2, '...    0.034683
# AutoEncoder {'batch_size': 4, 'dropout': 0, 'ep...    0.036941

# %%
# Desvios Padrão
std_score_table = scores.groupby('CLASSIFICADOR').std().sort_values(by=['F1'], ascending=True)
std_score_table.to_csv(r'./results/1-1_anomaly_detection_scores_desvios_padrao_simuladas.csv')
std_score_table
# Out:
#                                                     PRECISAO  REVOGACAO  \
# CLASSIFICADOR
# AutoEncoder {'batch_size': 4, 'dropout': 0, 'ep...  0.183019   0.183019
# AutoEncoder {'batch_size': 8, 'dropout': 0, 'ep...  0.183493   0.183493
# AutoEncoder {'batch_size': 4, 'dropout': 0, 'ep...  0.183571   0.183571
# AutoEncoder {'batch_size': 4, 'dropout': 0.2, '...  0.183586   0.183586
# AutoEncoder {'batch_size': 4, 'dropout': 0.2, '...  0.183849   0.183849
# AutoEncoder {'batch_size': 8, 'dropout': 0.2, '...  0.184099   0.184099
# AutoEncoder {'batch_size': 8, 'dropout': 0.2, '...  0.184138   0.184138
# AutoEncoder {'batch_size': 8, 'dropout': 0, 'ep...  0.184370   0.184370
#
#                                                           F1  TREINAMENTO [s]  \
# CLASSIFICADOR
# AutoEncoder {'batch_size': 4, 'dropout': 0, 'ep...  0.183019         0.389287
# AutoEncoder {'batch_size': 8, 'dropout': 0, 'ep...  0.183493         0.571998
# AutoEncoder {'batch_size': 4, 'dropout': 0, 'ep...  0.183571         0.776828
# AutoEncoder {'batch_size': 4, 'dropout': 0.2, '...  0.183586         0.597415
# AutoEncoder {'batch_size': 4, 'dropout': 0.2, '...  0.183849         0.693377
# AutoEncoder {'batch_size': 8, 'dropout': 0.2, '...  0.184099         0.832642
# AutoEncoder {'batch_size': 8, 'dropout': 0.2, '...  0.184138         0.825590
# AutoEncoder {'batch_size': 8, 'dropout': 0, 'ep...  0.184370         0.695747
#
#                                                     TESTE [s]
# CLASSIFICADOR
# AutoEncoder {'batch_size': 4, 'dropout': 0, 'ep...    0.077983
# AutoEncoder {'batch_size': 8, 'dropout': 0, 'ep...    0.017203
# AutoEncoder {'batch_size': 4, 'dropout': 0, 'ep...    0.001317
# AutoEncoder {'batch_size': 4, 'dropout': 0.2, '...    0.042427
# AutoEncoder {'batch_size': 4, 'dropout': 0.2, '...    0.001208
# AutoEncoder {'batch_size': 8, 'dropout': 0.2, '...    0.026224
# AutoEncoder {'batch_size': 8, 'dropout': 0.2, '...    0.001258
# AutoEncoder {'batch_size': 8, 'dropout': 0, 'ep...    0.001310

# %%
# Calcular tempo total do notebook Jupyter
print(f'Tempo total de execução (hh:mm:ss.ms): {datetime.now() - start_time}')
# Out:
# Tempo total de execução (hh:mm:ss.ms): 1:24:26.742708

# %% [markdown]
# ## Análise

# %% [markdown]
# Tendo em vista os resultados apresentados acima, foram identificados os melhores parâmetros de camadas para o classificador de rede neural:
#
# - Autoencoder: {'batch_size': 8, 'dropout': 0, 'epochs': 10, 'hidden_neurons': [4, 2, 2, 4]}
#
# Esses parâmetros serão utilizados na etapa subsequente (avaliação em instâncias reais).
